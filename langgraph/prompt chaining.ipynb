# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from langgraph.graph import StateGraph,START,END
from typing import TypedDict

# %%
load_dotenv()
model = ChatGroq(
    model="meta-llama/llama-4-scout-17b-16e-instruct"
)

# %%
class Blogstate(TypedDict):
    title :str
    outline :str
    content :str

# %%
def create_outline(state :Blogstate) -> Blogstate:
    #fetch title 
    title = state['title']
    #call llm
    prompt = f"generate a detailed outline for a blog on the topic : {title}"
    outline = model.invoke(prompt).content
    #update state
    state['outline'] = outline
    return state

# %%
def create_blog (state : Blogstate) -> Blogstate:
    title = state['title']
    outline = state['outline']
    prompt = f'write a detailed  blog on the title {title} using the following outline {outline}'
    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(Blogstate)
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initial_state = {"title":"rise of AI in India"}
final_state =  workflow.invoke(initial_state)
print(final_state)
# Out:
# {'title': 'rise of AI in India', 'outline': 'Here is a detailed outline for a blog on the topic "Rise of AI in India":\n\n**Title:** "The Rise of AI in India: A New Era of Innovation and Transformation"\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance in the global economy\n* Context of India\'s emergence as a major player in the AI landscape\n* Thesis statement: India is rapidly becoming a hub for AI innovation, with significant implications for the country\'s economy, industries, and society.\n\n**II. Background: India\'s IT Industry and AI Adoption**\n\n* Overview of India\'s IT industry: history, growth, and current status\n* Early adoption of AI in India: initial applications, challenges, and limitations\n* Factors driving AI adoption in India: data availability, talent pool, and government initiatives\n\n**III. Current State of AI in India**\n\n* **AI Startups:** growth of AI startups in India, notable examples (e.g., Flipkart, Ola, Paytm)\n* **AI Research:** overview of AI research in India, top institutions, and research areas (e.g., computer vision, NLP)\n* **Industry Adoption:** AI adoption across industries in India: BFSI, healthcare, retail, manufacturing, and more\n\n**IV. Government Initiatives and Policies**\n\n* **National Strategy for Artificial Intelligence (NSAI):** overview of the policy, goals, and objectives\n* **AI-related initiatives:** Make in India, Digital India, and other relevant programs\n* **Regulatory framework:** current regulatory environment, challenges, and proposed solutions\n\n**V. Applications and Use Cases**\n\n* **Healthcare:** AI applications in healthcare, such as diagnostics, personalized medicine, and patient care\n* **Finance:** AI in BFSI: risk management, credit scoring, and customer service\n* **Transportation:** AI in transportation: autonomous vehicles, traffic management, and route optimization\n* **Education:** AI in education: personalized learning, adaptive assessments, and teacher support\n\n**VI. Challenges and Limitations**\n\n* **Data Quality and Availability:** challenges related to data collection, storage, and sharing\n* **Talent and Skills:** shortage of skilled AI professionals, education, and training programs\n* **Ethics and Bias:** concerns around AI bias, fairness, and transparency\n\n**VII. Future Outlook and Opportunities**\n\n* **Emerging Trends:** future trends in AI, such as edge AI, explainable AI, and transfer learning\n* **New Industries and Applications:** potential AI applications in emerging areas, such as agriculture, energy, and environmental sustainability\n* **India\'s Global Leadership:** India\'s potential to become a global leader in AI research, innovation, and adoption\n\n**VIII. Conclusion**\n\n* Recap of India\'s AI journey and current status\n* Call to action: what needs to be done to sustain India\'s AI growth and maximize its benefits\n* Final thoughts: India\'s AI future and its implications for the country and the world.\n\nThis outline provides a comprehensive framework for a blog on the rise of AI in India. You can expand or modify it as per your requirements and writing style. Good luck with your blog!', 'content': "**The Rise of AI in India: A New Era of Innovation and Transformation**\n\n**Introduction**\n\nArtificial Intelligence (AI) has emerged as a transformative force in the global economy, revolutionizing industries, and redefining the way businesses operate. As one of the fastest-growing major economies in the world, India has been at the forefront of this AI revolution. With a rich talent pool, supportive government policies, and a thriving startup ecosystem, India is rapidly becoming a hub for AI innovation. This blog provides an in-depth analysis of the rise of AI in India, exploring its background, current state, government initiatives, applications, challenges, and future outlook.\n\n**Background: India's IT Industry and AI Adoption**\n\nIndia's IT industry has a r ...

# %%
print(final_state['outline'])
# Out:
# Here is a detailed outline for a blog on the topic "Rise of AI in India":
#
# **Title:** "The Rise of AI in India: A New Era of Innovation and Transformation"
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance in the global economy
# * Context of India's emergence as a major player in the AI landscape
# * Thesis statement: India is rapidly becoming a hub for AI innovation, with significant implications for the country's economy, industries, and society.
#
# **II. Background: India's IT Industry and AI Adoption**
#
# * Overview of India's IT industry: history, growth, and current status
# * Early adoption of AI in India: initial applications, challenges, and limitations
# * Factors driving AI adoption in India: data availability, talent pool, and government initiatives
#
# **III. Current State of AI in India**
#
# * **AI Startups:** growth of AI startups in India, notable examples (e.g., Flipkart, Ola, Paytm)
# * **AI Research:** overview of AI research in India, top institutions, and research areas (e.g., computer vision, NLP)
# * **Industry Adoption:** AI adoption across industries in India: BFSI, healthcare, retail, manufacturing, and more
#
# **IV. Government Initiatives and Policies**
#
# * **National Strategy for Artificial Intelligence (NSAI):** overview of the policy, goals, and objectives
# * **AI-related initiatives:** Make in India, Digital India, and other relevant programs
# * **Regulatory framework:** current regulatory environment, challenges, and proposed solutions
#
# **V. Applications and Use Cases**
#
# * **Healthcare:** AI applications in healthcare, such as diagnostics, personalized medicine, and patient care
# * **Finance:** AI in BFSI: risk management, credit scoring, and customer service
# * **Transportation:** AI in transportation: autonomous vehicles, traffic management, and route optimization
# * **Education:** AI in education: personalized learning, adaptive assessments, and teacher support
#
# **VI. Challenges and Limitations**
#
# * **Data Quality and Availability:** challenges related to data collection, storage, and sharing
# * **Talent and Skills:** shortage of skilled AI professionals, education, and training programs
# * **Ethics and Bias:** concerns around AI bias, fairness, and transparency
#
# **VII. Future Outlook and Opportunities**
#
# * **Emerging Trends:** future trends in AI, such as edge AI, explainable AI, and transfer learning
# * **New Industries and Applications:** potential AI applications in emerging areas, such as agriculture, energy, and environmental sustainability
# * **India's Global Leadership:** India's potential to become a global leader in AI research, innovation, and adoption
#
# **VIII. Conclusion**
#
# * Recap of India's AI journey and current status
# * Call to action: what needs to be done to sustain India's AI growth and maximize its benefits
# * Final thoughts: India's AI future and its implications for the country and the world.
#
# This outline provides a comprehensive framework for a blog on the rise of AI in India. You can expand or modify it as per your requirements and writing style. Good luck with your blog!
